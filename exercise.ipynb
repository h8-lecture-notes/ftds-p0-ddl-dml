# %% [markdown]
# # Exercise

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# create two tables, `books` and `authors` where 1 author can write many books and 1 book belongs to 1 author
# ![diagram.jpg](attachment:diagram.jpg)

# %%
-- code here

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# insert these datas into each table:
# - `authors`:
#     - J.K. Rowling - July 31, 1965
#     - Mark Manson - March 9, 1984
# - `books`:
#     - https://www.goodreads.com/book/show/41899.Fantastic_Beasts_and_Where_to_Find_Them?from_search=true&from_srp=true&qid=ELbB5Or3aR&rank=1
#     - https://www.goodreads.com/book/show/5.Harry_Potter_and_the_Prisoner_of_Azkaban?from_search=true&from_srp=true&qid=P8omaUBROP&rank=2
#     - https://www.goodreads.com/book/show/28257707-the-subtle-art-of-not-giving-a-f-ck?from_search=true&from_srp=true&qid=HfWnUFAmgv&rank=1

# %%
-- code here

# %% [markdown]
# update `J.K. Rowling`'s name to her real fullname

# %%
-- code here

# %% [markdown]
# delete one of the books in the library

# %%
-- code here
