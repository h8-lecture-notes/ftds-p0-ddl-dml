# %% [markdown]
# # SQL: DDL & DML

# %% [markdown]
# ## PostgreSQL Data Types

# %% [markdown]
# - numeric: int, serial, decimal
# - text/string: varchar, char, text
# - boolean: boolean
# - date: date, datetime, timestamp
# - and more here:
#     > https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-data-types

# %% [markdown]
# ## DDL

# %% [markdown]
# ### Create
#
# - create database
#     https://www.postgresqltutorial.com/postgresql-administration/postgresql-create-database/
# - create table
#     https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-create-table/

# %% [markdown]
# ### Alter
#
# - alter database https://www.postgresqltutorial.com/postgresql-administration/postgresql-alter-database/
# - alter table https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-alter-table/

# %% [markdown]
# ### Drop
#
# - drop database https://www.postgresqltutorial.com/postgresql-administration/postgresql-drop-database/
# - drop table https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-drop-table/

# %% [markdown]
# ### Truncate
#
# - truncate table https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-truncate-table/

# %% [markdown]
# ## DML

# %% [markdown]
# ### Insert
#
# - insert https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-insert/
# - insert multiple https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-insert-multiple-rows/
# - we can also use `select` statement inside insert process:
#     > https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-select-into/

# %% [markdown]
# ### Update
#
# - update data https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-update/

# %% [markdown]
# ### Delete
#
# - delete data https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-delete/

# %% [markdown]
# ## Additional: `Explain` Statement
#
# - **Explain** is very useful for understanding the performance of a Postgres query. It returns the execution plan generated by PostgreSQL query planner for a given statement.
# - Example https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-explain/

# %% [markdown]
# ## References

# %% [markdown]
# - Official Documentation https://www.postgresql.org/docs/current/
# - PostgreSQL Tutorial https://www.postgresqltutorial.com/
# - Understanding explain command https://isd-soft.com/tech_blog/postgresql-explaining-explain-command/
